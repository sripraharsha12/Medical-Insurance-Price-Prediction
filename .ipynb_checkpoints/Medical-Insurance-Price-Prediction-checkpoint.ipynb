# %% [markdown]
# #  Medical Insurance Price Prediction using Linear Regression
#
# ## 📌 Problem Statement
#
# Medical insurance companies estimate insurance charges based on various factors such as age, BMI, smoking habits, number of children, sex, and region.
#
# The objective of this project is to build a **Machine Learning model** that can accurately predict a person's **medical insurance charges** using these features.
#
# This project demonstrates the complete Machine Learning workflow, including data preprocessing, exploratory data analysis (EDA), feature engineering, model training, and performance evaluation using **Linear Regression**.
#
# ---
#
# # 📂 Dataset
#
# The dataset contains information about individuals and their medical insurance charges.
#
# ### Features
#
# - **Age** – Age of the primary beneficiary.
# - **Sex** – Gender of the individual (Male/Female).
# - **BMI** – Body Mass Index, which indicates body fat based on height and weight.
# - **Children** – Number of dependents covered by health insurance.
# - **Smoker** – Whether the individual is a smoker (Yes/No).
# - **Region** – Residential area of the individual.
# - **Charges** – Medical insurance charges billed by the insurance company (**Target Variable**).
#
# ---
#
# ## 🎯 Objective
#
# The main objective of this project is to:
#
# - Understand the dataset using Exploratory Data Analysis (EDA).
# - Preprocess the data for machine learning.
# - Train a **Linear Regression** model.
# - Predict medical insurance charges for new individuals.
# - Evaluate the model using appropriate performance metrics.
#
# ---
#
# ## 🛠️ Technologies Used
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Load Dataset

# %%
df=pd.read_csv("insurance.csv")

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) helps us understand the dataset before building a machine learning model.
#
# It helps identify:
#
# - Missing values
# - Data types
# - Feature distributions
# - Relationships between variables
# - Outliers

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %% [markdown]
# # 1. Insurance Charges Distribution

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["charges"], kde=True)
plt.title("Distribution of Insurance Charges")
plt.savefig("Images/charges_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# # 2. Age Distribution

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["age"], kde=True)
plt.title("Age Distribution")
plt.savefig("Images/age_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# # 3. BMI Distribution

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["bmi"], kde=True)
plt.title("BMI Distribution")
plt.savefig("Images/bmi_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# # 4. Smoker vs Non-Smoker

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="smoker", data=df)
plt.title("Smoker vs Non-Smoker")
plt.savefig("Images/SmokervsNonSmoker_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # 📈 Simple Linear Regression
#
# Simple Linear Regression uses **one independent feature** to predict the target variable.
#
# In this project, we use **Age** to predict Insurance Charges.

# %%
X=df[["age"]]
y=df["charges"]

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,y,alpha=0.6)
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Age vs Charges")
plt.show()

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.4, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Slope:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Slope: [251.29757077]
# Intercept: 3202.9074717321673

# %%
y_pred=model.predict(X_test)
print(y_pred[:10])
# Out:
# [15516.48843954 10490.53702411 16019.08358109 10993.13216565
#  10993.13216565 15516.48843954  8982.75159948  8731.45402871
#  14008.70301491 15516.48843954]

# %%
comparison=pd.DataFrame({
    "Actual":y_test.values,
    "predicted":y_pred})
print(comparison)
# Out:
#           Actual     predicted
# 0     8688.85885  15516.488440
# 1     5708.86700  10490.537024
# 2    11436.73815  16019.083581
# 3    38746.35510  10993.132166
# 4     4463.20510  10993.132166
# ..           ...           ...
# 530   8733.22925  14762.595727
# 531   3558.62025   9987.941883
# 532   2585.85065   8480.156458
# 533  10156.78320  15516.488440
# 534  43921.18370  17275.571435
#
# [535 rows x 2 columns]

# %% [markdown]
# # 📏 Model Evaluation
#
# The trained model is evaluated using:
#
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² Score

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", MAE)
print("Mean Squared Error:", MSE)
print("Root Mean Squared Error:", RMSE)
print("R² Score:", R2)
# Out:
# Mean Absolute Error: 9353.080934502097
# Mean Squared Error: 151658466.23997894
# Root Mean Squared Error: 12314.969193626874
# R² Score: 0.08292161102423146

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,y,alpha=0.6, color="lightblue", label="Actual Data")
plt.plot(X,model.predict(X), color="red",label="Predicted Data")
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Age vs Charges")
plt.legend()

plt.show()

# %%
coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_
})

coefficients = coefficients.sort_values(by="Coefficient", ascending=False)
plt.figure(figsize=(8,5))
plt.bar(coefficients["Feature"], coefficients["Coefficient"])
plt.title("Feature Importance")
plt.ylabel("Coefficient")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# # ⚙️ Data Preprocessing
#
# Before training the model, categorical features must be converted into numerical values because machine learning algorithms work only with numerical data.

# %%
df["smoker"] = df["smoker"].str.strip().str.lower()

# %%
df["smoker"] = df["smoker"].map({ "no": 0, "yes": 1})
df["sex"] = df["sex"].map({"male": 0, "female": 1})
df = pd.get_dummies(df, columns=["region"], drop_first=True)

# %%
print(df.isnull().sum())
print(df["smoker"].unique())
print(df["sex"].unique())

print(df.dtypes)
# Out:
# age                 0
# sex                 0
# bmi                 0
# children            0
# smoker              0
# charges             0
# region_northwest    0
# region_southeast    0
# region_southwest    0
# dtype: int64
# [1 0]
# [1 0]
# age                   int64
# sex                   int64
# bmi                 float64
# children              int64
# smoker                int64
# charges             float64
# region_northwest       bool
# region_southeast       bool
# region_southwest       bool
# dtype: object

# %% [markdown]
# # 📈 Multiple Linear Regression
#
# Multiple Linear Regression uses **multiple independent features** to predict the target variable.
#
# Features used:
#
# - Age
# - BMI
# - Sex
# - Smoker

# %%
X = df.drop("charges", axis=1)
y = df["charges"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_})

coefficients.sort_values(
    by="Coefficient",
    ascending=False)
# Out:
#             Feature   Coefficient
# 4            smoker  22874.446407
# 3          children    522.155362
# 2               bmi    328.383096
# 0               age    251.246172
# 1               sex    111.907161
# 5  region_northwest   -465.746596
# 7  region_southwest   -765.583886
# 6  region_southeast   -936.099326

# %%
y_pred=model.predict(X_test)
print(y_pred[:10])
# Out:
# [ 8075.91965807  5499.00278769 14345.71219595 31428.2037203
#   8874.78160711 13108.23558267 30222.44619694  1224.76010921
#  10576.43395847 11204.40476605]

# %%
comparison=pd.DataFrame({
    "Actual":y_test.values,
    "predicted":y_pred})
print(comparison)
# Out:
#           Actual     predicted
# 0     8688.85885   8075.919658
# 1     5708.86700   5499.002788
# 2    11436.73815  14345.712196
# 3    38746.35510  31428.203720
# 4     4463.20510   8874.781607
# ..           ...           ...
# 397   5148.55260   7402.454695
# 398  11363.28320  13855.552581
# 399  10600.54830  12204.364397
# 400  13429.03540  13575.906155
# 401  24603.04837   8226.425299
#
# [402 rows x 2 columns]

# %% [markdown]
# ## 📏 Model Evaluation
#
# The trained model is evaluated using:
#
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² ScoreModel Evaluation

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", MAE)
print("Mean Squared Error:", MSE)
print("Root Mean Squared Error:", RMSE)
print("R² Score:", R2)
# Out:
# Mean Absolute Error: 4181.815956942297
# Mean Squared Error: 38940169.92282636
# Root Mean Squared Error: 6240.205919905718
# R² Score: 0.7724363518631283

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred)
plt.plot( [y.min(), y.max()], [y.min(), y.max()], "r--", linewidth=2, label="Perfect Prediction")
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.title("Actual vs Predicted Insurance Charges")
plt.legend()
plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(8,6))
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted Charges")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["charges"], bins=30)
plt.xlabel("Charges")
plt.ylabel("Count")
plt.title("Distribution of Insurance Charges")
plt.show()

# %%
# Sample customer
sample = pd.DataFrame({
    "age": [30],
    "sex": [1],                 # Male = 1 (change according to your encoding)
    "bmi": [28.5],
    "children": [2],
    "smoker": [0],              # No = 0
    "region_northwest": [0],
    "region_southeast": [1],
    "region_southwest": [0]
})

prediction = model.predict(sample)

print("="*50)
print("        Medical Charges Prediction")
print("="*50)
print(f"👤 Age        : 30")
print(f"⚖️ BMI        : 28.5")
print(f"👨‍👩‍👧 Children   : 2")
print(f"🚬 Smoker     : No")
print(f"📍 Region      : Southeast")
print("-"*50)
print(f"💰 Predicted Insurance Charges : ${prediction[0]:,.2f}")
# Out:
# ...
#         Medical Charges Prediction
# ...
# 👤 Age        : 30
# ⚖️ BMI        : 28.5
# 👨‍👩‍👧 Children   : 2
# 🚬 Smoker     : No
# 📍 Region      : Southeast
# --------------------------------------------------
# 💰 Predicted Insurance Charges : $5,487.73

# %% [markdown]
# # ✅ Conclusion
#
# In this project, a Linear Regression model was successfully developed to predict medical insurance charges.
#
# The project covered:
#
# - Exploratory Data Analysis (EDA)
# - Data Preprocessing
# - Simple Linear Regression
# - Multiple Linear Regression
# - Model Evaluation
# - Prediction
#
# This project helped me understand the complete machine learning workflow, from raw data to prediction using a real-world dataset.
#
#
# # Final Comparison
#
# | Model | R² Score | Performance |
# |--------|----------|-------------|
# | Single Linear Regression | 0.09 | Poor |
# | Multiple Linear Regression | 0.772 | Good |
#
# The comparison shows that using multiple relevant features significantly improves the predictive performance of the model.
